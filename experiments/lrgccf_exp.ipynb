# %% [markdown]
# ### Setup

# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import pandas as pd

from common.utils import DataPreprocessor, FeatureEngineer, set_seed
from common.exp_data_utils import ExperimentDataPreprocessor
from common.eval import Evaluator

MOVIELENS_DATA_DIR = "../datasets/hetrec2011-movielens-2k-v2/user_ratedmovies.dat"
RANDOM_SEED = 42

# Initialize data processors
set_seed(RANDOM_SEED)
data_preprocessor = DataPreprocessor()
feature_engineer = FeatureEngineer()
experiment_data_preprocessor = ExperimentDataPreprocessor()
evaluator = Evaluator()
# Out:
# /home/adam/R11_Bai/DPRecSys/.venv/lib/python3.11/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# Seed set to 42
# Seed set to 42
# random seed set to 42
# numpy seed set to 42
# torch seed set to 42
# lightning seed set to 42
# torch set to use deterministic algorithms

# %% [markdown]
# ### Load and Process DataFrame

# %%
interaction_df = data_preprocessor.load_and_process_df(
    file_dir=MOVIELENS_DATA_DIR,
    year_range=(2006, 2008),
    rating_threshold=4.0,
)
interaction_df.head()
# Out:
# Data count: 855598
# Data count after filtering by year (2006, 2008): 480608
# Num of distinct users: 2103
# Num of distinct items: 9519
# done!
# ------------------------------
# Filtering by min user/item interactions (10/0):
# Data count before: 480608
# Data count after: 480448
# done!
# ------------------------------
# ==== Final Data Info: ====
# Data Year Range: (2006, 2008)
# Rating Threshold: 4.0
# Num of interactions: 480448
# Num of distinct users: 2064
# Num of distinct items: 9519
#    userID  movieID  rating  date_day  date_month  date_year  date_hour  \
# 0      75        3     1.0        29          10       2006         23
# 1      75       32     4.5        29          10       2006         23
# 2      75      110     4.0        29          10       2006         23
# 3      75      160     2.0        29          10       2006         23
# 4      75      163     4.0        29          10       2006         23
#
#    date_minute  date_second           timestamp  label
# 0           17           16 2006-10-29 23:17:16      0
# 1           23           44 2006-10-29 23:23:44      1
# 2           30            8 2006-10-29 23:30:08      1
# 3           16           52 2006-10-29 23:16:52      0
# 4           29           30 2006-10-29 23:29:30      1

# %% [markdown]
# ### Join Side Information

# %%
interaction_info_df = data_preprocessor.join_item_features(
    df=interaction_df, actor_k=5, threshold=5,
)
interaction_info_df.head()
# Out:
# extracting item features...
# merging features...
# interaction data count before merging: 480448
# interaction data count after merging: 478404
# done!
#    userID  movieID  rating  date_day  date_month  date_year  date_hour  \
# 0      75        3     1.0        29          10       2006         23
# 1      75       32     4.5        29          10       2006         23
# 2      75      110     4.0        29          10       2006         23
# 3      75      160     2.0        29          10       2006         23
# 4      75      163     4.0        29          10       2006         23
#
#    date_minute  date_second           timestamp  label  \
# 0           17           16 2006-10-29 23:17:16      0
# 1           23           44 2006-10-29 23:23:44      1
# 2           30            8 2006-10-29 23:30:08      1
# 3           16           52 2006-10-29 23:16:52      0
# 4           29           30 2006-10-29 23:29:30      1
#
#                                              actorID country  \
# 0  [jack_lemmon, walter_matthau, annmargret, burg...     USA
# 1           [[RARE], [RARE], [RARE], [RARE], [RARE]]     USA
# 2  [mel_gibson, sophie_marceau, patrick_mcgoohan,...     USA
# 3  [[RARE], laura_linney, ernie_hudson_jr, tim_cu...     USA
# 4  [antonio_banderas, salma_hayek, 1142520-joaqui...     USA
#
#          directorID        directorName  \
# 0     donald_petrie       Donald Petrie
# 1            [RARE]  Siddharth Randeria
# 2            [RARE]          Mel Gibson
# 3    frank_marshall      Frank Marshall
# 4  robert_rodriguez    Robert Rodriguez
#
#                                                genre
# 0  [Comedy, Romance, [PAD], [PAD], [PAD], [PAD], ...
# 1  [Sci-Fi, Thriller, [PAD], [PAD], [PAD], [PAD],...
# 2  [Action, Drama, War, [PAD], [PAD], [PAD], [PAD...
# 3  [Action, Adventure, Mystery, Sci-Fi, [PAD], [P...
# 4  [Action, Romance, Thriller, [PAD], [PAD], [PAD...

# %% [markdown]
# ### Prepare Train/Valid/Test Set

# %%
# TODO: determine which method to use for splitting
# 1. Split by year
# 2. Stratified split by user, timestamp

train_df, valid_df, test_df = experiment_data_preprocessor.stratified_time_split(
    interaction_info_df,
    time_col="timestamp",
    train_ratio=0.64,
    val_ratio=0.16,
    test_ratio=0.20,
)

TRAIN_NUM_USERS = len(train_df["userID"].unique())
TRAIN_NUM_ITEMS = len(train_df["movieID"].unique())
# Out:
# Splitting data into train/valid/test by time period with ratio=(0.64 : 0.16 : 0.2):
# train: 305206 (63.8%)
# valid: 75578 (15.8%)
# test: 97620 (20.41%)
# ------------------------------
#
# Check target label distribution after splitting (%):
# train label
# 0    0.547669
# 1    0.452331
# Name: proportion, dtype: float64
# valid label
# 0    0.606737
# 1    0.393263
# Name: proportion, dtype: float64
# test label
# 0    0.590914
# 1    0.409086
# Name: proportion, dtype: float64

# %% [markdown]
# ### Re-index User/Item ID & Encode Categorical Features

# %%
print("Train: fit_transform")
encoded_train_df = feature_engineer.fit_transform(train_df)
print("---"*10)
print("Valid: transform")
encoded_valid_df = feature_engineer.transform(valid_df)
print("---"*10)
print("Test: transform")
encoded_test_df = feature_engineer.transform(test_df)
print("---"*10)
# Out:
# Train: fit_transform
# Re-index mapping dumped into ...
# user: ../datasets/userid_mapping.csv
# item: ../datasets/itemid_mapping.csv
# Fitted: user/item mapping
# Fitted: vocab2idx for actorID
# Fitted: vocab2idx for country
# Fitted: vocab2idx for directorID
# Fitted: vocab2idx for genre
# Transformed: Re-index user/item mapping
# Transformed: Encoded idx for actorID
# Transformed: Encoded idx for country
# Transformed: Encoded idx for directorID
# Transformed: Encoded idx for genre
# ------------------------------
# Valid: transform
# Transformed: Re-index user/item mapping
# Transformed: Encoded idx for actorID
# Transformed: Encoded idx for country
# Transformed: Encoded idx for directorID
# Transformed: Encoded idx for genre
# ------------------------------
# Test: transform
# Transformed: Re-index user/item mapping
# Transformed: Encoded idx for actorID
# Transformed: Encoded idx for country
# Transformed: Encoded idx for directorID
# Transformed: Encoded idx for genre
# ------------------------------

# %%
# # NOTE: can check the encoding vocab idx content from the feature engineer
# oov_idx = feature_engineer.vocab2idx["movieID"]["[OOV]"]
# len(test_df[test_df["movieID"] == oov_idx])

# %% [markdown]
# ### Prepare Additional Data for Train/Inference

# %% [markdown]
# #### Build bi-partite graph for training

# %%
# NOTE: At training, we use interaction graph from train_df for train and validation
train_graph = experiment_data_preprocessor.create_interaction_graph(encoded_train_df)

# NOTE: At inference, we can use graph of (train_df + valid_df)
# train_valid_graph = utils.create_interaction_graph(pd.concat([train_df, valid_df], axis=0))
# Out:
# Creating interaction graph...
# Drop negative samples
#   Num of all interactions: 305206
#   Num of positive interactions: 138054
#
# Building edges...
# Building labels...
# Interaction Graph: Data(edge_index=[2, 276107], edge_label=[138054])
# Edge Index: tensor([[    0,     0,     0,  ..., 10448, 10452, 10453],
#         [ 2089,  2200,  2315,  ...,  1760,  1645,  1760]])

# %% [markdown]
# #### Prepare train/valid triplet data

# %%
train_triplet_df = experiment_data_preprocessor.prepare_triplet_df(encoded_train_df, k_negative_samples=5)
valid_triplet_df = experiment_data_preprocessor.prepare_triplet_df(encoded_valid_df, k_negative_samples=5) # TODO: use TripletDataset for validation as well
train_triplet_df.head(1)
# Out:
# Original data count (positive samples): 138054
# Num of triplets: 138054(pos samples) * 5(negative sampled items) = 690270
# Original data count (positive samples): 29722
# Num of triplets: 29722(pos samples) * 5(negative sampled items) = 148610
#    userID  pos_item_id  neg_item_id                   actorID_idx  \
# 0       0         1082         2876  [2267, 1401, 582, 998, 1847]
#
#    country_idx  directorID_idx                   genre_idx    neg_actorID_idx  \
# 0           37             360  [2, 3, 17, 18, 0, 0, 0, 0]  [147, 1, 1, 1, 1]
#
#    neg_country_idx  neg_directorID_idx             neg_genre_idx
# 0               37                   1  [6, 0, 0, 0, 0, 0, 0, 0]

# %% [markdown]
# ### Prepare DataLoader

# %%
# NOTE: ensure reproducibility of DataLoader
import torch
from common.utils import seed_worker
g = torch.Generator()
g.manual_seed(RANDOM_SEED)

# TODO: determine which Dataset to use
from torch.utils.data import DataLoader
from common.datasets import TripletDataset, UserItemPairDataset

BATCH_SIZE = 1024

train_dataset = TripletDataset(train_triplet_df)
valid_dataset = TripletDataset(valid_triplet_df)  # TODO: use TripletDataset for validation as well
print("train data count:", len(train_dataset))
print("valid data count:", len(valid_dataset))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, worker_init_fn=seed_worker, generator=g, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE)
# Out:
# train data count: 690270
# valid data count: 148610

# %% [markdown]
# ### Configure Model (LightningModule)

# %%
from lightning_models.extensions.lrgccf import LRGCCFRec

EMB_DIM = 64
LR = 1e-3
EPOCHS = 50
NUM_LAYERS = 3
REG_WEIGHT = 1e-3

model = LRGCCFRec(
    graph_data=train_graph,
    num_users=TRAIN_NUM_USERS,
    num_items=TRAIN_NUM_ITEMS,
    embedding_dim=EMB_DIM,
    num_layers=NUM_LAYERS,
    lr=LR,
    reg_weight=REG_WEIGHT,
)
# Out:
# Seed set to 42

# %% [markdown]
# ### Configure Trainer and Experiment

# %%
from common._mlflow import get_mlflow_logger, get_callbacks

EXPERIMENT_NAME = "lrgccf-exp"
VERSION = "prod"
RUN_NAME = "run02"
PATIENCE = 5
mlflow_logger = get_mlflow_logger(experiment_name=EXPERIMENT_NAME, run_name=RUN_NAME, tags={"version": VERSION})
trainer_callbacks = get_callbacks(
    exp_name=EXPERIMENT_NAME,
    version_name=VERSION,
    run_name=RUN_NAME,
    patience=PATIENCE,
    monitor_metric="val_bpr_loss",
    monitor_mode="min",
    min_delta=0.01,
    hyper_param_str=f"emb_dim={EMB_DIM}-num_layers={NUM_LAYERS}-lr={LR}-reg_weight={REG_WEIGHT}",
)

# %%
from pytorch_lightning import Trainer

trainer = Trainer(
    max_epochs=EPOCHS,
    logger=mlflow_logger,
    log_every_n_steps=50,
    callbacks=trainer_callbacks,
    accelerator='gpu',  # or 'auto', 'gpu'
    devices=[1], # if gpu is available
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %% [markdown]
# ### Train Model

# %%
# Start training
trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=valid_loader)
# Out:
# /home/adam/R11_Bai/DPRecSys/.venv/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:654: Checkpoint directory /home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name         | Type    | Params | Mode
# -------------------------------------------------
# 0 | lrgccf_model | LRGCCF  | 669 K  | train
# 1 | bpr_loss     | BPRLoss | 0      | train
# 2 | reg_loss     | EmbLoss | 0      | train
# -------------------------------------------------
# 669 K     Trainable params
# 0         Non-trainable params
# 669 K     Total params
# 2.678     Total estimated model params size (MB)
# 12        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/adam/R11_Bai/DPRecSys/.venv/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_bpr_loss improved. New best score: 4.425
# Epoch 0, global step 675: 'val_bpr_loss' reached 4.42460 (best 4.42460), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=00-val_bpr_loss=4.42.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_bpr_loss improved by 0.073 >= min_delta = 0.01. New best score: 4.351
# Epoch 1, global step 1350: 'val_bpr_loss' reached 4.35137 (best 4.35137), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=01-val_bpr_loss=4.35.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_bpr_loss improved by 0.037 >= min_delta = 0.01. New best score: 4.314
# Epoch 2, global step 2025: 'val_bpr_loss' reached 4.31390 (best 4.31390), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=02-val_bpr_loss=4.31.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_bpr_loss improved by 0.019 >= min_delta = 0.01. New best score: 4.294
# Epoch 3, global step 2700: 'val_bpr_loss' reached 4.29449 (best 4.29449), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=03-val_bpr_loss=4.29.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 4, global step 3375: 'val_bpr_loss' reached 4.28486 (best 4.28486), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=04-val_bpr_loss=4.28.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Metric val_bpr_loss improved by 0.015 >= min_delta = 0.01. New best score: 4.280
# Epoch 5, global step 4050: 'val_bpr_loss' reached 4.27955 (best 4.27955), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=05-val_bpr_loss=4.28.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 6, global step 4725: 'val_bpr_loss' reached 4.27650 (best 4.27650), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=06-val_bpr_loss=4.28.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 7, global step 5400: 'val_bpr_loss' reached 4.27427 (best 4.27427), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=07-val_bpr_loss=4.27.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 8, global step 6075: 'val_bpr_loss' reached 4.27283 (best 4.27283), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=08-val_bpr_loss=4.27.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Epoch 9, global step 6750: 'val_bpr_loss' reached 4.27164 (best 4.27164), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=09-val_bpr_loss=4.27.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# Monitored metric val_bpr_loss did not improve in the last 5 records. Best score: 4.280. Signaling Trainer to stop.
# Epoch 10, global step 7425: 'val_bpr_loss' reached 4.27055 (best 4.27055), saving model to '/home/adam/R11_Bai/DPRecSys/experiments/test_checkpoints/lrgccf-exp/[prod]-run02-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=10-val_bpr_loss=4.27.ckpt' as top 1
# 🏃 View run run02 at: http://140.112.106.216:3683/#/experiments/21/runs/7d1b4de727f54255a13c4cbb59ef7fe8
# 🧪 View experiment at: http://140.112.106.216:3683/#/experiments/21

# %% [markdown]
# ### Inference

# %% [markdown]
# #### Prepare prediction pool for inference/testing

# %%
# NOTE: Prepare prediction pool to evaluate the model
seen_df = pd.concat([encoded_train_df, encoded_valid_df], ignore_index=True)
prediction_pool_df = experiment_data_preprocessor.prepare_prediction_df(encoded_test_df, seen_df, K=-1)
prediction_pool_df.tail()
# Out:
# Prediction DataFrame:
# User Pool: 2064
# Item Pool: 8397, negative sampled to -1 items for each user
# Num of interactions: 2064(users) * -1(items) = 16952432
#           userID  movieID  label                     actorID_idx  country_idx  \
# 16952427    2063     8392      0  [2214, 1834, 1886, 2036, 1214]           37
# 16952428    2063     8393      0            [1070, 110, 1, 1, 1]           12
# 16952429    2063     8394      0              [1782, 1, 1, 1, 0]           36
# 16952430    2063     8395      0           [1, 1733, 935, 24, 1]           37
# 16952431    2063     8396      0                 [1, 1, 0, 0, 0]           17
#
#           directorID_idx                   genre_idx
# 16952427               1    [6, 0, 0, 0, 0, 0, 0, 0]
# 16952428             308    [9, 0, 0, 0, 0, 0, 0, 0]
# 16952429             365    [4, 6, 0, 0, 0, 0, 0, 0]
# 16952430             443  [9, 17, 18, 0, 0, 0, 0, 0]
# 16952431               1    [9, 0, 0, 0, 0, 0, 0, 0]

# %%
from torch.utils.data import DataLoader
from common.datasets import UserItemPairDataset

BATCH_SIZE = 1024
test_dataset = UserItemPairDataset(prediction_pool_df)
print("test data count:", len(test_dataset))
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
# Out:
# test data count: 16952432

# %%
# NOTE: the inference model MUST be the same as the training model
# best_model_experiment_name = "lrgccf-exp"
# best_model_checkpoint_path = "[prod]-run00-emb_dim=64-num_layers=3-lr=0.001-reg_weight=0.001-best-checkpoint-epoch=01-val_bpr_loss=0.51-v1.ckpt"
# best_model_path = f"test_checkpoints/{best_model_experiment_name}/{best_model_checkpoint_path}"
best_model_path = trainer.checkpoint_callback.best_model_path

model = LRGCCFRec.load_from_checkpoint(checkpoint_path=best_model_path)
# start inference
trainer.test(model=model, dataloaders=test_loader)
# Out:
# Seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /home/adam/R11_Bai/DPRecSys/.venv/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:425: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        test_ndcg10        │   0.0037326316814869642   │
# │        test_ndcg20        │   0.008490764535963535    │
# │        test_ndcg5         │   0.001352465245872736    │
# │     test_precision10      │   0.0010658914688974619   │
# │     test_precision20      │   0.0015746124554425478   │
# │      test_precision5      │   0.0005813953466713428   │
# │       test_recall10       │   0.0003820779384113848   │
# │       test_recall20       │   0.0012534796260297298   │
# │       test_recall5        │   8.377776248380542e-05   │
# └───────────────────────────┴───────────────────────────┘
# 🏃 View run run02 at: http://140.112.106.216:3683/#/experiments/21/runs/7d1b4de727f54255a13c4cbb59ef7fe8
# 🧪 View experiment at: http://140.112.106.216:3683/#/experiments/21
# [{'test_ndcg5': 0.001352465245872736,
#   'test_ndcg10': 0.0037326316814869642,
#   'test_ndcg20': 0.008490764535963535,
#   'test_precision5': 0.0005813953466713428,
#   'test_precision10': 0.0010658914688974619,
#   'test_precision20': 0.0015746124554425478,
#   'test_recall5': 8.377776248380542e-05,
#   'test_recall10': 0.0003820779384113848,
#   'test_recall20': 0.0012534796260297298}]

# %%
model.test_results["eval_score_df"].describe()
# Out:
#               user       ndcg@5     recall@5  precision@5      ndcg@10  \
# count  2064.000000  2064.000000  2064.000000  2064.000000  2064.000000
# mean   1031.500000     0.001352     0.000084     0.000581     0.003733
# std     595.969798     0.025517     0.001742     0.010770     0.037816
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     515.750000     0.000000     0.000000     0.000000     0.000000
# 50%    1031.500000     0.000000     0.000000     0.000000     0.000000
# 75%    1547.250000     0.000000     0.000000     0.000000     0.000000
# max    2063.000000     0.630930     0.045455     0.200000     0.630930
#
#          recall@10  precision@10      ndcg@20    recall@20  precision@20
# count  2064.000000   2064.000000  2064.000000  2064.000000   2064.000000
# mean      0.000382      0.001066     0.008491     0.001253      0.001575
# std       0.004342      0.010733     0.050815     0.009057      0.009530
# min       0.000000      0.000000     0.000000     0.000000      0.000000
# 25%       0.000000      0.000000     0.000000     0.000000      0.000000
# 50%       0.000000      0.000000     0.000000     0.000000      0.000000
# 75%       0.000000      0.000000     0.000000     0.000000      0.000000
# max       0.083333      0.200000     0.630930     0.166667      0.150000

# %%
user_dps_df = evaluator.eval_user_diversity_preference_scale(encoded_train_df, feature_engineer.vocab2idx, normalized=True)

# Evaluate user diversity preference matching score (DPMS) at k
eval_df = evaluator.prepare_evaluation_data(model.test_results, feature_engineer.idx2vocab)

# Get user DPMS
user_dpms_df = evaluator.evaluate_dpms_at_k(
    eval_df=eval_df,
    feature_engineer=feature_engineer,
    ground_truth_dps_df=user_dps_df,
    k=10,
    actor_k=5,
    rare_threshold=5,
)

user_dpms_df.describe()
# Out:
# Calculating user diversity preference scale:   0%|          | 0/2064 [00:00<?, ?it/s]
# Calculating user diversity preference scale: 100%|██████████| 2064/2064 [00:06<00:00, 301.63it/s]
# candidate item pool size: 10
# exploded 2064
# extracting item features...
# merging features...
# interaction data count before merging: 20639
# interaction data count after merging: 20639
# done!
# Transformed: Re-index user/item mapping
# Transformed: Encoded idx for actorID
# Transformed: Encoded idx for country
# Transformed: Encoded idx for directorID
# Transformed: Encoded idx for genre
# encoded 2064
# Calculating user diversity preference scale: 100%|██████████| 2064/2064 [00:04<00:00, 495.82it/s]
# combined_df 2064
# Calculating DPMS for each feature...
#             userID  actorID_dpms  country_dpms  directorID_dpms   genre_dpms  \
# count  2064.000000   2064.000000   2064.000000      2064.000000  2064.000000
# mean   1031.500000      0.047859      0.943986         0.029039     0.773854
# std     595.969798      0.033353      0.061499         0.048184     0.112088
# min       0.000000      0.000000      0.285922         0.000000     0.296508
# 25%     515.750000      0.022861      0.931264         0.000000     0.712643
# 50%    1031.500000      0.043530      0.963925         0.000000     0.796524
# 75%    1547.250000      0.069520      0.980108         0.045213     0.856855
# max    2063.000000      0.195820      0.999641         0.373428     0.965376
#
#           avg_dpms
# count  2064.000000
# mean      0.448684
# std       0.039398
# min       0.238966
# 25%       0.426308
# 50%       0.453153
# 75%       0.475652
# max       0.563796

# %%
# ILS@10
raw_eval_df = evaluator.prepare_evaluation_data(model.test_results)
ils_df = evaluator.evaluate_ils_at_k(raw_eval_df, k=10)
ils_df.describe()
# Out:
#               user       ILS@10
# count  2064.000000  2064.000000
# mean   1031.500000     0.230972
# std     595.969798     0.067920
# min       0.000000     0.058889
# 25%     515.750000     0.181920
# 50%    1031.500000     0.226058
# 75%    1547.250000     0.271726
# max    2063.000000     0.534722

# %%
# import joblib
# dir = "artifacts/lrgccf"
# prefix = "lrgccf_k_all"
# if not os.path.exists(dir):
#     os.makedirs(dir)

# joblib.dump(eval_df, os.path.join(dir, f"{prefix}_eval_df.pkl"))
# joblib.dump(user_dps_df, os.path.join(dir, f"user_dps_df.pkl"))
# joblib.dump(feature_engineer, os.path.join(dir, f"feature_engineer.pkl"))

# %%
# embedding_path = "embeddings/lrgccf/"
# if not os.path.exists(embedding_path):
#     os.makedirs(embedding_path)

# torch.save(model.user_emb.cpu(), f"{embedding_path}user_emb.pt")
# torch.save(model.item_emb.cpu(), f"{embedding_path}item_emb.pt")
